# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
name="Naimat ullah"
print("Name:\t", name)
print("Father Name:\tRehmat ullah")
DOB="06-02-2003"
print("My Date of Birth is:\t", DOB)
# Out:
# Name:	 Naimat ullah
# Father Name:	Rehmat ullah
# My Date of Birth is:	 06-02-2003

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name="Naimat ullah"
age= 23
profession="engineer"
education="BE (mechanical)"
print(f"my name is {name.upper()}, I am {age} years old. My education is {education} and I am professionally an {profession}")
# Out:
# my name is NAIMAT ULLAH, I am 23 years old. My education is BE (mechanical) and I am professionally an engineer

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a=5; b=10;
sum=a+b
sub=a-b
mul=a*b 
div=b/a
exp=b**a
rem=b%5
print(f"Sum: {sum}\nSubtraction: {sub}\nMultiplication: {mul}\nDivision: {div}\nExponentiation: {exp}\nRemainder: {rem}")
# Out:
# Sum: 15
# Subtraction: -5
# Multiplication: 50
# Division: 2.0
# Exponentiation: 100000
# Remainder: 0

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
e=75; i=82; m=90; totalMarks= 300;
percentage= (e+i+m)/totalMarks*100
print(f"{percentage}%")
# Out:
# 82.33333333333334%

# %% [markdown]
# 5. Take the values of two variables `a` and `b`, then swap their values without using a third variable and print the result before and after swapping

# %%
# Write your code here

# %% [markdown]
# 6. Take the radius of a circle from a variable and calculate its Area and Circumference (use `pi = 3.14159`)

# %%
unit=input("enter the unit you are working on: ")
pi = 3.14159
r = float(input("Enter the radius of the circle: "))
area = pi*r** 2
circumference=2*pi*r
print(f"The circle having radius {r} have area {area}{unit}^2 and circumference of {circumference}{unit}.")
# Out:
# The circle having radius 3.6 have area 40.7150064mm^2 and circumference of 22.619448mm.

# %% [markdown]
# 7. Take the price of an item and a discount percentage in variables, then calculate and print the discount amount and the final price after discount

# %%
actualPrice=float(input("Enter the actual price of the product: "))
discountPercentage=float(input("Enter the discount percentage value b/w 1-100: "))
discountedPrice=actualPrice-(actualPrice*discountPercentage/100)
print(f"Actual Price: {actualPrice}\nDiscount Percentage: {discountPercentage}\nDiscounted Price: {discountedPrice}")
# Out:
# Actual Price: 5.0
# Discount Percentage: 2.0
# Discounted Price: 4.9
